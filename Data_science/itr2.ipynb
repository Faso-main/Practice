# %%
"""
Import snippet
"""
import numpy as np
import pandas as pd
import os

# %%
raw_data=pd.read_csv("data.csv", header=0, sep=",")

#print(f'Result\n{raw_data}\n')

raw_data.dropna(axis=0,inplace=True)
#print(f'\nRemove blank rows: \n{raw_data}')

#print(raw_data.info())

raw_data['Average_Pulse']=raw_data['Average_Pulse'].astype(float)
raw_data['Max_Pulse']=raw_data['Max_Pulse'].astype(float)

#print(raw_data.info())

print(f'Describe: {raw_data.describe()}')
